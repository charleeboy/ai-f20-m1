# %%
# Start writing code here...def celcius (a_string):
def celcius (a_string):
    out = a_string.replace("°", "")
    cel= round((int(out) - 32) * 5.0/9.0)
    return cel

#  --------Classes scraped --------
#  DetailsSummary--highTempValue--3x6cL - High Temprature
#  DDetailsSummary--lowTempValue--1DlJK - low Temprature
#  DetailsSummary--daypartName--1Mebr - date & day of weeek Temprature
#  DailyContent--narrative--3AcXd - Summary


def scrape ():
    import requests                  # Import request - use to get html from weather.com
    import pandas as pd              # Import pandas - use to display weather date in data frame
    from bs4 import BeautifulSoup

    page =requests.get("https://weather.com/weather/tenday/l/San+Francisco+CA?canonicalCityId=dfdaba8cbe3a4d12a8796e1f7b1ccc7174b4b0a2d5ddb1c8566ae9f154fa638c")
    soup =BeautifulSoup(page.content, 'html.parser')
    rows_list = []

    header = soup.findAll("details", {"summarycontentclassname": "DaypartDetails--DetailSummaryContent--1c28m"})
    for each in header:
        weatherResults = {}
        date = []
        date = each.find("h2", {"class": "DetailsSummary--daypartName--1Mebr"}).get_text(strip=True).split()
        weatherResults["Day of Week"] = date[0]
        if len(date) == 2:
            weatherResults["Day Date"] =  date[1]
        else:
            weatherResults["Day Date"] = ""
            
        weatherResults["Temp High"] = celcius(each.find("span", {"class": "DetailsSummary--highTempValue--3x6cL"}).get_text(strip=True)) # DetailsSummary--highTempValue--3x6cL
        weatherResults["Temp Low"] = celcius(each.find("span", {"class": "DetailsSummary--lowTempValue--1DlJK"}).get_text(strip=True))  # DetailsSummary--lowTempValue--1DlJK
        weatherResults["Summary"] = each.find("p", {"class": "DailyContent--narrative--3AcXd"}).get_text(strip=True)                    # DailyContent--narrative--3AcXd
        rows_list.append(weatherResults)                               
                                  
    df = pd.DataFrame(rows_list)    
    return df
scrape ()
# Out:
#    Day of Week Day Date  Temp High  Temp Low  \
# 0        Today                  17         7
# 1          Thu       10         13         7
# 2          Fri       11         13         7
# 3          Sat       12         13         8
# 4          Sun       13         14         8
# 5          Mon       14         14         7
# 6          Tue       15         13         7
# 7          Wed       16         14         7
# 8          Thu       17         14         7
# 9          Fri       18         14         7
# 10         Sat       19         15         7
# 11         Sun       20         16         6
# 12         Mon       21         15         6
# 13         Tue       22         16         5
# 14         Wed       23         16         6
#
#                                               Summary
# 0   Partly cloudy. High 63F. Winds N at 10 to 15 mph.
# 1   A few passing clouds, otherwise generally sunn...
# 2   Partly to mostly cloudy. High near 55F. Winds ...
# 3   Overcast with rain showers at times. High 56F....
# 4   Rain early...then remaining cloudy with shower...
# 5   Intervals of clouds and sunshine. High 57F. Wi...
# 6   Sunshine and clouds mixed. High 56F. Winds W a...
# 7   Increasing clouds with showers arriving someti...
# 8   Cloudy with occasional rain showers. High 57F....
# 9   A few showers early with mostly cloudy conditi...
# 10  Rain showers early with mostly cloudy conditio...
# 11  Considerable clouds early. Some decrease in cl...
# 12  Sunshine and clouds mixed. High 59F. Winds NW ...
# 13  A few clouds from time to time. High near 60F....
# 14  A few clouds from time to time. High around 60...
